# %% [markdown]
# <a href="https://colab.research.google.com/github/jgh0707/NLP_2023/blob/main/%EB%94%94%EC%A7%80%ED%84%B8%EC%9D%B8%EB%AC%B8%ED%95%99%20%EC%8B%A4%EC%8A%B575.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #디지털인문학 실습 과제75
# ##23.12.07
# ##복습

# %%
text = open ('/content/sample_data/text_symbol_sample.txt', 'rt')
obj = text.read().replace('\n', ' ')
obj.split()
# Out:
# ['Here’s',
#  'to',
#  'the',
#  'crazy',
#  'ones,',
#  'the',
#  'misfits,',
#  'the',
#  'rebels,',
#  'the',
#  'troublemakers,',
#  'the',
#  'round',
#  'pegs',
#  'in',
#  'the',
#  'square',
#  'holes.',
#  'The',
#  'ones',
#  'who',
#  'see',
#  'things',
#  'differently',
#  '—',
#  'they’re',
#  'not',
#  'fond',
#  'of',
#  'rules.',
#  'I',
#  'wanted',
#  'to',
#  'pay',
#  'with',
#  'a',
#  'twenti-dolloar',
#  'bill;',
#  'however,',
#  'she',
#  'couldn’t',
#  'get',
#  'cash.',
#  'I’ve',
#  'got',
#  'a',
#  'big',
#  'trouble,',
#  'but',
#  'other',
#  'people',
#  'were',
#  'having',
#  'lots',
#  'of',
#  'fun.',
#  'Anna',
#  'likes',
#  'Brown’s',
#  'East',
#  'back',
#  'pack,',
#  'but',
#  'her',
#  'brother',
#  'doesn’t.']

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

print('Tokenizing Word and Punctuation:',word_tokenize(obj))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Tokenizing Word and Punctuation: ['Here', '’', 's', 'to', 'the', 'crazy', 'ones', ',', 'the', 'misfits', ',', 'the', 'rebels', ',', 'the', 'troublemakers', ',', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', '.', 'The', 'ones', 'who', 'see', 'things', 'differently', '—', 'they', '’', 're', 'not', 'fond', 'of', 'rules', '.', 'I', 'wanted', 'to', 'pay', 'with', 'a', 'twenti-dolloar', 'bill', ';', 'however', ',', 'she', 'couldn', '’', 't', 'get', 'cash', '.', 'I', '’', 've', 'got', 'a', 'big', 'trouble', ',', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', '.', 'Anna', 'likes', 'Brown', '’', 's', 'East', 'back', 'pack', ',', 'but', 'her', 'brother', 'doesn', '’', 't', '.']

# %%
from pprint import pprint
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
result1 = word_tokenize(obj)

print('Tokenizing Word and Punctuation: %s' %result1)
# Out:
# Tokenizing Word and Punctuation: ['Here', '’', 's', 'to', 'the', 'crazy', 'ones', ',', 'the', 'misfits', ',', 'the', 'rebels', ',', 'the', 'troublemakers', ',', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', '.', 'The', 'ones', 'who', 'see', 'things', 'differently', '—', 'they', '’', 're', 'not', 'fond', 'of', 'rules', '.', 'I', 'wanted', 'to', 'pay', 'with', 'a', 'twenti-dolloar', 'bill', ';', 'however', ',', 'she', 'couldn', '’', 't', 'get', 'cash', '.', 'I', '’', 've', 'got', 'a', 'big', 'trouble', ',', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', '.', 'Anna', 'likes', 'Brown', '’', 's', 'East', 'back', 'pack', ',', 'but', 'her', 'brother', 'doesn', '’', 't', '.']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import WordPunctTokenizer

print('Tokenizing Words and Punctuations:', WordPunctTokenizer().tokenize(obj))
# Out:
# Tokenizing Words and Punctuations: ['Here', '’', 's', 'to', 'the', 'crazy', 'ones', ',', 'the', 'misfits', ',', 'the', 'rebels', ',', 'the', 'troublemakers', ',', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', '.', 'The', 'ones', 'who', 'see', 'things', 'differently', '—', 'they', '’', 're', 'not', 'fond', 'of', 'rules', '.', 'I', 'wanted', 'to', 'pay', 'with', 'a', 'twenti', '-', 'dolloar', 'bill', ';', 'however', ',', 'she', 'couldn', '’', 't', 'get', 'cash', '.', 'I', '’', 've', 'got', 'a', 'big', 'trouble', ',', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', '.', 'Anna', 'likes', 'Brown', '’', 's', 'East', 'back', 'pack', ',', 'but', 'her', 'brother', 'doesn', '’', 't', '.']

# %%
from nltk.tokenize import WordPunctTokenizer
result2 = WordPunctTokenizer().tokenize(obj)

print('Tokenizing Words and Punctuations: %s' %result2)
# Out:
# Tokenizing Words and Punctuations: ['Here', '’', 's', 'to', 'the', 'crazy', 'ones', ',', 'the', 'misfits', ',', 'the', 'rebels', ',', 'the', 'troublemakers', ',', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', '.', 'The', 'ones', 'who', 'see', 'things', 'differently', '—', 'they', '’', 're', 'not', 'fond', 'of', 'rules', '.', 'I', 'wanted', 'to', 'pay', 'with', 'a', 'twenti', '-', 'dolloar', 'bill', ';', 'however', ',', 'she', 'couldn', '’', 't', 'get', 'cash', '.', 'I', '’', 've', 'got', 'a', 'big', 'trouble', ',', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', '.', 'Anna', 'likes', 'Brown', '’', 's', 'East', 'back', 'pack', ',', 'but', 'her', 'brother', 'doesn', '’', 't', '.']

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence

print('Tokenizing Words after Cleaning Punctuations:', text_to_word_sequence(obj))
# Out:
# Tokenizing Words after Cleaning Punctuations: ['here’s', 'to', 'the', 'crazy', 'ones', 'the', 'misfits', 'the', 'rebels', 'the', 'troublemakers', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', 'the', 'ones', 'who', 'see', 'things', 'differently', '—', 'they’re', 'not', 'fond', 'of', 'rules', 'i', 'wanted', 'to', 'pay', 'with', 'a', 'twenti', 'dolloar', 'bill', 'however', 'she', 'couldn’t', 'get', 'cash', 'i’ve', 'got', 'a', 'big', 'trouble', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', 'anna', 'likes', 'brown’s', 'east', 'back', 'pack', 'but', 'her', 'brother', 'doesn’t']

# %%
from tensorflow.keras.preprocessing.text import text_to_word_sequence
result3 = text_to_word_sequence(obj)

print('Tokenizing Words after Cleaning Punctuations: %s' %result3)
# Out:
# Tokenizing Words after Cleaning Punctuations: ['here’s', 'to', 'the', 'crazy', 'ones', 'the', 'misfits', 'the', 'rebels', 'the', 'troublemakers', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', 'the', 'ones', 'who', 'see', 'things', 'differently', '—', 'they’re', 'not', 'fond', 'of', 'rules', 'i', 'wanted', 'to', 'pay', 'with', 'a', 'twenti', 'dolloar', 'bill', 'however', 'she', 'couldn’t', 'get', 'cash', 'i’ve', 'got', 'a', 'big', 'trouble', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', 'anna', 'likes', 'brown’s', 'east', 'back', 'pack', 'but', 'her', 'brother', 'doesn’t']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
tokenized_sentence = word_tokenize(obj)

[stemmer.stem(w) for w in tokenized_sentence]
# Out:
# ['here',
#  '’',
#  's',
#  'to',
#  'the',
#  'crazi',
#  'one',
#  ',',
#  'the',
#  'misfit',
#  ',',
#  'the',
#  'rebel',
#  ',',
#  'the',
#  'troublemak',
#  ',',
#  'the',
#  'round',
#  'peg',
#  'in',
#  'the',
#  'squar',
#  'hole',
#  '.',
#  'the',
#  'one',
#  'who',
#  'see',
#  'thing',
#  'differ',
#  '—',
#  'they',
#  '’',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rule',
#  '.',
#  'i',
#  'want',
#  'to',
#  'pay',
#  'with',
#  'a',
#  'twenti-dolloar',
#  'bill',
#  ';',
#  'howev',
#  ',',
#  'she',
#  'couldn',
#  '’',
#  't',
#  'get',
#  'cash',
#  '.',
#  'i',
#  '’',
#  've',
#  'got',
#  'a',
#  'big',
#  'troubl',
#  ',',
#  'but',
#  'other',
#  'peopl',
#  'were',
#  'have',
#  'lot',
#  'of',
#  'fun',
#  '.',
#  'anna',
#  'like',
#  'brown',
#  '’',
#  's',
#  'east',
#  'back',
#  'pack',
#  ',',
#  'but',
#  'her',
#  'brother',
#  'doesn',
#  '’',
#  't',
#  '.']

# %% [markdown]
# ###코드가 이어지는 코드이기에 저번에 배운 내용 추가 ↑

# %%
from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer("[\w]+")
result4= retokenize.tokenize(obj)

print('Tokenizing Words with RegexpTokenizer: %s' %result4)
# Out:
# Tokenizing Words with RegexpTokenizer: ['Here', 's', 'to', 'the', 'crazy', 'ones', 'the', 'misfits', 'the', 'rebels', 'the', 'troublemakers', 'the', 'round', 'pegs', 'in', 'the', 'square', 'holes', 'The', 'ones', 'who', 'see', 'things', 'differently', 'they', 're', 'not', 'fond', 'of', 'rules', 'I', 'wanted', 'to', 'pay', 'with', 'a', 'twenti', 'dolloar', 'bill', 'however', 'she', 'couldn', 't', 'get', 'cash', 'I', 've', 'got', 'a', 'big', 'trouble', 'but', 'other', 'people', 'were', 'having', 'lots', 'of', 'fun', 'Anna', 'likes', 'Brown', 's', 'East', 'back', 'pack', 'but', 'her', 'brother', 'doesn', 't']

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()
[stemmer.stem(w) for w in result4]
# Out:
# ['her',
#  's',
#  'to',
#  'the',
#  'crazy',
#  'on',
#  'the',
#  'misfit',
#  'the',
#  'rebel',
#  'the',
#  'troublemak',
#  'the',
#  'round',
#  'peg',
#  'in',
#  'the',
#  'squ',
#  'hol',
#  'the',
#  'on',
#  'who',
#  'see',
#  'thing',
#  'diff',
#  'they',
#  're',
#  'not',
#  'fond',
#  'of',
#  'rul',
#  'i',
#  'want',
#  'to',
#  'pay',
#  'with',
#  'a',
#  'twent',
#  'dollo',
#  'bil',
#  'howev',
#  'she',
#  'couldn',
#  't',
#  'get',
#  'cash',
#  'i',
#  've',
#  'got',
#  'a',
#  'big',
#  'troubl',
#  'but',
#  'oth',
#  'peopl',
#  'wer',
#  'hav',
#  'lot',
#  'of',
#  'fun',
#  'ann',
#  'lik',
#  'brown',
#  's',
#  'east',
#  'back',
#  'pack',
#  'but',
#  'her',
#  'broth',
#  'doesn',
#  't']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
[lemmatizer.lemmatize(w) for w in result4]

# %%
import os

# %%
os.mkdir("txtdata")

# %%
# !pip install corpus-toolkit
# Out:
# Collecting corpus-toolkit
#   Downloading corpus_toolkit-0.32-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 8.2 MB/s eta 0:00:00
# Installing collected packages: corpus-toolkit
# Successfully installed corpus-toolkit-0.32

# %%
from urllib.request import urlopen

url = "https://raw.githubusercontent.com/ms624atyale/Temp_Data/main/PG_Aesop_NoQuotesAllText.txt"

os.system("curl " + url + " > txtdata.txt")
file= open("txtdata.txt")
text = file.read().replace("\n", " ")
file.close()

# %%
from urllib.request import urlopen

# %%
from corpus_toolkit import corpus_tools as ct
mydata = ct.ldcorpus("txtdata")
tok_corp = ct.tokenize(mydata)
for token in tok_corp:
  print(token)
#txtdata.txt 파일 생성 후 txtdata 폴더에 삽입해야 실행 가능
count = len(token)
print(count)
# Out:
# Processing txtdata.txt (1 of 1 files)
# ['there', 'be', 'once', 'a', 'little', 'kid', 'whose', 'grow', 'horn', 'make', 'he', 'think', 'he', 'be', 'a', 'grown-up', 'billy', 'goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'so', 'one', 'even', 'when', 'the', 'flock', 'start', 'home', 'from', 'the', 'pasture', 'and', 'he', 'mother', 'call', 'the', 'kid', 'pay', 'no', 'heed', 'and', 'keep', 'right', 'on', 'nibble', 'the', 'tender', 'grass', 'a', 'little', 'late', 'when', 'he', 'lift', 'he', 'head', 'the', 'flock', 'be', 'go', 'he', 'be', 'all', 'alone', 'the', 'sun', 'be', 'sink', 'long', 'shadow', 'come', 'creep', 'over', 'the', 'ground', 'a', 'chilly', 'little', 'wind', 'come', 'creep', 'with', 'they', 'make', 'scary', 'noise', 'in', 'the', 'grass', 'the', 'kid', 'shiver', 'a', 'he', 'think', 'of', 'the', 'terrible', 'wolf', 'then', 'he', 'start', 'wildly', 'over', 'the', 'field', 'bleat', 'for', 'he', 'mother', 'but', 'not', 'half-way', 'near', 'a', 'clump', 'of', 'tree', 'there', 'be', 'the', 'wolf', 'the', 'kid', 'know', 'there', 'be', 'little', 'hope', 'for', 'he', 'please', 'mr', 'wolf', 'he', 'say', 'tremble', 'i', 'know', 'you', 'be', 'go', 'to', 'eat', 'i', 'but', 'first', 'please', 'pipe', 'i', 'a', 'tune', 'for', 'i', 'want', 'to', 'dance', 'and', 'be', 'merry', 'a', 'long', 'a', 'i', 'canthe', 'wolf', 'like', 'the', 'idea', 'of', 'a', 'little', 'music', 'before', 'eat', 'so', 'he', 'strike', 'up', 'a', 'merry', 'tune', 'and', 'the', 'kid', 'leap', 'and', 'frisk', 'gaily', 'meanwhile', 'the', 'flock', 'be', 'move', 'slowly', 'homeward', 'in', 'the', 'still', 'even', 'air', 'the', 'wolf', 'pipe', 'carry', 'far', 'the', 'shepherd', 'dog', 'prick', 'up', 'they', 'ear', 'they', 'recognize', 'the', 'song', 'the', 'wolf', 'sing', 'before', 'a', 'feast', 'and', 'in', 'a', 'moment', 'they', 'be', 'race', 'back', 'to', 'the', 'pasture', 'the', 'wolf', 'song', 'end', 'suddenly', 'and', 'a', 'he', 'run', 'with', 'the', 'dog', 'at', 'he', 'heel', 'he', 'call', 'himself', 'a', 'fool', 'for', 'turn', 'piper', 'to', 'please', 'a', 'kid', 'when', 'he', 'should', 'have', 'stick', 'to', 'he', 'butcher', 'trade', 'do', 'not', 'let', 'anything', 'turn', 'you', 'from', 'you', 'purpose', 'the', 'tortoise', 'you', 'know', 'carry', 'he', 'house', 'on', 'he', 'back', 'no', 'matter', 'how', 'hard', 'he', 'try', 'he', 'cannot', 'leave', 'home', 'they', 'say', 'that', 'jupiter', 'punish', 'he', 'so', 'because', 'he', 'be', 'such', 'a', 'lazy', 'stay-at-home', 'that', 'he', 'would', 'not', 'go', 'to', 'jupiters', 'wedding', 'even', 'when', 'especially', 'invite', 'after', 'many', 'year', 'tortoise', 'begin', 'to', 'wish', 'he', 'have', 'go', 'to', 'that', 'wedding', 'when', 'he', 'see', 'how', 'gaily', 'the', 'bird', 'fly', 'about', 'and', 'how', 'the', 'hare', 'and', 'the', 'chipmunk', 'and', 'all', 'the', 'other', 'animal', 'run', 'nimbly', 'by', 'always', 'eager', 'to', 'see', 'everything', 'there', 'be', 'to', 'be', 'see', 'the', 'tortoise', 'feel', 'very', 'sad', 'and', 'discontented', 'he', 'want', 'to', 'see', 'the', 'world', 'too', 'and', 'there', 'he', 'be', 'with', 'a', 'house', 'on', 'he', 'back', 'and', 'little', 'short', 'leg', 'that', 'could', 'hardly', 'drag', 'he', 'along', 'one', 'day', 'he', 'meet', 'a', 'pair', 'of', 'duck', 'and', 'tell', 'they', 'all', 'he', 'trouble', 'we', 'can', 'help', 'you', 'to', 'see', 'the', 'world', 'say', 'the', 'duck', 'take', 'hold', 'of', 'this', 'stick', 'with', 'you', 'tooth', 'and', 'we', 'will', 'carry', 'you', 'far', 'up', 'in', 'the', 'air', 'where', 'you', 'can', 'see', 'the', 'whole', 'countryside', 'but', 'keep', 'quiet', 'or', 'you', 'will', 'be', 'sorry', 'the', 'tortoise', 'be', 'very', 'glad', 'indeed', 'he', 'seize', 'the', 'stick', 'firmly', 'with', 'he', 'tooth', 'the', 'two', 'duck', 'take', 'hold', 'of', 'it', 'one', 'at', 'each', 'end', 'and', 'away', 'they', 'sail', 'up', 'toward', 'the', 'cloud', 'just', 'then', 'a', 'crow', 'fly', 'by', 'he', 'be', 'very', 'much', 'astonish', 'at', 'the', 'strange', 's ...
# 25618

# %%
mydata = ct.frequency(mydata)

# %%
ct.write_corpus("tagged_txt",ct.tag(ct.ldcorpus("txtdata")))
# Out:
# Processing txtdata.txt (1 of 1 files)

# %%
tagged_freq = ct.frequency(ct.reload("tagged_txt"))
ct.head(tagged_freq, hits = 10)
# Out:
# Processing 1.txt (1 of 1 files)
# the_DET	1911
# a_DET	832
# be_AUX	831
# and_CCONJ	775
# he_PRON	761
# to_PART	566
# of_ADP	504
# his_PRON	360
# in_ADP	353
# you_PRON	313

# %%
type(tagged_freq)
# Out:
# dict

# %%
import pandas as pd

# %%
data_dict = tagged_freq
data_items= data_dict.items()
data_list = list(data_items)
print(data_list)
# Out:
# [('there_PRON', 39), ('be_VERB', 32), ('once_ADV', 34), ('a_DET', 832), ('little_ADJ', 42), ('kid_NOUN', 4), ('whose_DET', 8), ('grow_VERB', 14), ('horn_NOUN', 20), ('make_VERB', 97), ('he_PRON', 761), ('think_VERB', 50), ('be_AUX', 831), ('grown_NOUN', 1), ('up_ADP', 102), ('Billy_PROPN', 1), ('Goat_PROPN', 19), ('and_CCONJ', 775), ('able_ADJ', 9), ('to_PART', 566), ('take_VERB', 58), ('care_NOUN', 12), ('of_ADP', 504), ('himself_PRON', 48), ('so_ADV', 141), ('one_NUM', 128), ('evening_NOUN', 14), ('when_SCONJ', 123), ('the_DET', 1911), ('flock_NOUN', 14), ('start_VERB', 9), ('home_ADV', 8), ('from_ADP', 83), ('pasture_NOUN', 11), ('his_PRON', 360), ('mother_NOUN', 11), ('call_VERB', 27), ('Kid_PROPN', 10), ('pay_VERB', 8), ('no_DET', 39), ('heed_NOUN', 1), ('keep_VERB', 33), ('right_ADV', 7), ('on_ADP', 133), ('nibble_VERB', 4), ('tender_ADJ', 5), ('grass_NOUN', 7), ('later_ADV', 9), ('lift_VERB', 3), ('head_NOUN', 42), ('go_VERB', 72), ('all_ADV', 19), ('alone_ADJ', 2), ('sun_NOUN', 9), ('sink_VERB', 5), ('long_ADJ', 23), ('shadow_NOUN', 11), ('came_AUX', 6), ('creep_VERB', 5), ('over_ADP', 19), ('ground_NOUN', 13), ('chilly_ADV', 1), ('wind_NOUN', 9), ('with_ADP', 204), ('they_PRON', 287), ('scary_ADJ', 1), ('noise_NOUN', 3), ('in_ADP', 353), ('shiver_VERB', 2), ('as_SCONJ', 128), ('terrible_ADJ', 5), ('Wolf_PROPN', 95), ('then_ADV', 70), ('wildly_ADV', 2), ('field_NOUN', 19), ('bleat_VERB', 1), ('for_ADP', 183), ('but_CCONJ', 193), ('not_PART', 256), ('half_ADJ', 1), ('way_NOUN', 33), ('near_ADP', 19), ('clump_NOUN', 1), ('tree_NOUN', 28), ('know_VERB', 53), ('hope_NOUN', 3), ('please_INTJ', 14), ('Mr._PROPN', 7), ('say_VERB', 158), ('tremble_VERB', 4), ('I_PRON', 280), ('you_PRON', 313), ('eat_VERB', 48), ('first_ADV', 13), ('pipe_VERB', 1), ('tune_NOUN', 3), ('for_SCONJ', 22), ('want_VERB', 17), ('dance_VERB', 6), ('merry_ADJ', 1), ('as_ADV', 38), ('long_ADV', 12), ('can_AUX', 60), ('like_VERB', 4), ('idea_NOUN', 7), ('music_NOUN', 3), ('before_ADP', 12), ('eating_NOUN', 1), ('strike_VERB', 8), ('merry_NOUN', 1), ('leap_VERB', 7), ('frisk_VERB', 3), ('gaily_ADV', 2), ('meanwhile_ADV', 2), ('move_VERB', 7), ('slowly_ADV', 6), ('homeward_ADJ', 2), ('still_ADJ', 1), ('air_NOUN', 8), ("'s_PART", 85), ('piping_NOUN', 1), ('carry_VERB', 33), ('far_ADV', 25), ('Shepherd_PROPN', 22), ('Dogs_PROPN', 14), ('prick_VERB', 2), ('their_PRON', 75), ('ear_NOUN', 8), ('recognize_VERB', 1), ('song_NOUN', 8), ('sing_NOUN', 1), ('feast_NOUN', 9), ('moment_NOUN', 11), ('race_VERB', 1), ('back_ADV', 14), ('to_ADP', 228), ('end_VERB', 3), ('suddenly_ADV', 5), ('run_VERB', 42), ('at_ADP', 174), ('heel_NOUN', 9), ('fool_NOUN', 8), ('turn_VERB', 19), ('piper_NOUN', 1), ('please_VERB', 9), ('should_AUX', 34), ('have_AUX', 221), ('stick_VERB', 8), ('butcher_NOUN', 4), ('trade_NOUN', 3), ('do_AUX', 120), ('let_VERB', 40), ('anything_PRON', 14), ('your_PRON', 84), ('purpose_NOUN', 1), ('Tortoise_PROPN', 13), ('house_NOUN', 12), ('back_NOUN', 10), ('no_ADV', 13), ('matter_ADV', 4), ('how_SCONJ', 51), ('hard_ADV', 3), ('try_VERB', 35), ('leave_VERB', 28), ('home_NOUN', 19), ('that_SCONJ', 132), ('Jupiter_PROPN', 16), ('punish_VERB', 5), ('because_SCONJ', 15), ('such_DET', 9), ('lazy_ADJ', 1), ('stay_VERB', 8), ('that_PRON', 106), ('would_AUX', 80), ('wedding_NOUN', 4), ('even_ADV', 22), ('especially_ADV', 3), ('invite_VERB', 2), ('after_ADP', 18), ('many_ADJ', 22), ('year_NOUN', 4), ('begin_VERB', 30), ('wish_VERB', 8), ('that_DET', 42), ('see_VERB', 112), ('bird_NOUN', 20), ('fly_VERB', 35), ('about_ADV', 7), ('Hare_PROPN', 13), ('Chipmunk_PROPN', 1), ('all_DET', 68), ('other_ADJ', 35), ('animal_NOUN', 13), ('nimbly_ADV', 1), ('by_ADP', 73), ('always_ADV', 21), ('eager_ADJ', 2), ('everything_PRON', 5), ('feel_VERB', 19), ('very_ADV', 147), ('sad_ADJ', 3), ('discontent_VERB', 1), ('world_NOUN', 17), ('too_ADV', 17), ('there_ADV', 42), ('short_ADJ', 7), ('leg_NOUN', 13), ('could_AUX', 77), ('hardly_ADV', 9), ('drag_VERB', 7), ('along_ADP', 22), ('day_N ...

# %%
df = pd.DataFrame(data_list)
df.columns = ["Tagged", "Freq"]
print(df)
# Out:
#                 Tagged  Freq
# 0           there_PRON    39
# 1              be_VERB    32
# 2             once_ADV    34
# 3                a_DET   832
# 4           little_ADJ    42
# ...                ...   ...
# 2995       circle_VERB     1
# 2996     boasting_NOUN     1
# 2997  chanticleer_NOUN     1
# 2998        rival_NOUN     1
# 2999       Pride_PROPN     1
#
# [3000 rows x 2 columns]

# %%
tagged = df["Tagged"]
pos = []
word = []

for i in range(0, len(tagged)):
  w = tagged[i]
  ws = w.split("_")
  word.append(ws[0])
  pos.append(ws[1])

print(len(tagged))
print(word[:10])
print(pos[:10])
# Out:
# 3000
# ['there', 'be', 'once', 'a', 'little', 'kid', 'whose', 'grow', 'horn', 'make']
# ['PRON', 'VERB', 'ADV', 'DET', 'ADJ', 'NOUN', 'DET', 'VERB', 'NOUN', 'VERB']

# %%
df["POS"] = pos
df["Word"] = word

cols = ["POS","Word","Freq"]
df = df[cols]

df = df.sort_values(by=['POS', 'Freq'], ascending = False)
print("Total rows: ", len(df))
df.head()
# Out:
# Total rows:  3000
#        POS    Word  Freq
# 1615     X  nearer     1
# 2400     X     ass     1
# 88    VERB     say   158
# 402   VERB    have   122
# 184   VERB     see   112

# %%
df1 = df[df["POS"] == "VERB"]
print(len(df1))

freq1 = list(df1["Freq"]); print(len(freq1))
txt1 = list(df1["Word"]); print(len(txt1))

import numpy as np
y = np.repeat(txt1, freq1, axis=0)
y = list(y)

txt2 = ' '.join(y); print(len(txt2))
print(txt2)
# Out:
# 690
# 690
# 690
# 20695
# say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say say have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have have see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see see make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make make get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get get come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come come go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go go do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do do find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find find take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take take know know know know know know know know know know know know know know know know know know kno ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud().generate(str(txt2))
plt.imshow(wc)

# %%
pos = "VERB" #@param = ["VERB","NOUN","ADJ","ADV"]
df1 = df[df["POS"] == pos]; print(len(df1))

# as list
freq1 = list(df1["Freq"])
txt1 = list(df1["Word"])

import numpy as np
y = np.repeat(txt1, freq1, axis=0)
y = list(y)

txt2 = ' '.join(y)

print(df[df["POS"] == pos])
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud(collocations = False).generate(str(txt2))
plt.imshow(wc)
# Out:
# 250
#       POS        Word  Freq
# 199   ADV        very   147
# 24    ADV          so   141
# 72    ADV        then    70
# 239   ADV        away    61
# 317   ADV        soon    55
# ...   ...         ...   ...
# 2891  ADV   strangely     1
# 2892  ADV      softly     1
# 2926  ADV  pleasantly     1
# 2934  ADV   meaningly     1
# 2953  ADV     loosely     1
#
# [250 rows x 3 columns]

# %%
pos = "NOUN" #@param = ["VERB","NOUN","ADJ","ADV"]
df1 = df[df["POS"] == pos]; print(len(df1))

# as list
freq1 = list(df1["Freq"])
txt1 = list(df1["Word"])

import numpy as np
y = np.repeat(txt1, freq1, axis=0)
y = list(y)

txt2 = ' '.join(y)

print(df[df["POS"] == pos])
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud(collocations = False).generate(str(txt2))
plt.imshow(wc)
# Out:
# 1169
#        POS         Word  Freq
# 211   NOUN          day    74
# 451   NOUN         time    63
# 49    NOUN         head    42
# 80    NOUN          way    33
# 311   NOUN        water    32
# ...    ...          ...   ...
# 2986  NOUN      thicket     1
# 2992  NOUN         gain     1
# 2996  NOUN     boasting     1
# 2997  NOUN  chanticleer     1
# 2998  NOUN        rival     1
#
# [1169 rows x 3 columns]

# %%
pos = "ADJ" #@param = ["VERB","NOUN","ADJ","ADV"]
df1 = df[df["POS"] == pos]; print(len(df1))

# as list
freq1 = list(df1["Freq"])
txt1 = list(df1["Word"])

import numpy as np
y = np.repeat(txt1, freq1, axis=0)
y = list(y)

txt2 = ' '.join(y)

print(df[df["POS"] == pos])
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud(collocations = False).generate(str(txt2))
plt.imshow(wc)
# Out:
# 447
#       POS        Word  Freq
# 299   ADJ        good    57
# 325   ADJ       great    53
# 4     ADJ      little    42
# 290   ADJ         old    36
# 191   ADJ       other    35
# ...   ...         ...   ...
# 2966  ADJ      brazen     1
# 2972  ADJ    restless     1
# 2977  ADJ  respectful     1
# 2980  ADJ    grandest     1
# 2988  ADJ       harsh     1
#
# [447 rows x 3 columns]

# %%
pos = "ADV" #@param = ["VERB","NOUN","ADJ","ADV"]
df1 = df[df["POS"] == pos]; print(len(df1))

# as list
freq1 = list(df1["Freq"])
txt1 = list(df1["Word"])

import numpy as np
y = np.repeat(txt1, freq1, axis=0)
y = list(y)

txt2 = ' '.join(y)

print(df[df["POS"] == pos])
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wc = WordCloud(collocations = False).generate(str(txt2))
plt.imshow(wc)
# Out:
# 250
#       POS        Word  Freq
# 199   ADV        very   147
# 24    ADV          so   141
# 72    ADV        then    70
# 239   ADV        away    61
# 317   ADV        soon    55
# ...   ...         ...   ...
# 2891  ADV   strangely     1
# 2892  ADV      softly     1
# 2926  ADV  pleasantly     1
# 2934  ADV   meaningly     1
# 2953  ADV     loosely     1
#
# [250 rows x 3 columns]
